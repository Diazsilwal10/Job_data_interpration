# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('LinkedInJobs_MLDataset.csv')

# %%
df.head(2).T
# Out:
#                                                                  0  \
# Co_Nm                                                  HearingLife
# Co_Pg_Lstd                                                    True
# Emp_Cnt                                                       1171
# Flw_Cnt                                                      11417
# Job_Ttl                                      Hearing Care Provider
# Job_Desc         Overview\n\nHearingLife is a national hearing ...
# Is_Supvsr                                                    False
# max_sal                                                     5250.0
# med_sal                                                     5250.0
# min_sal                                                     5250.0
# py_prd                                                     MONTHLY
# py_lstd                                                       True
# wrk_typ                                                  Full-time
# ...

# %%
df.describe()
# Out:
#              Emp_Cnt       Flw_Cnt       max_sal       med_sal        min_sal  \
# count   33246.000000  3.324600e+04  3.324600e+04  3.324600e+04   33246.000000
# mean    15484.558744  5.234364e+05  3.186615e+04  2.749495e+04   23123.763015
# std     62180.953563  2.708736e+06  6.823853e+04  5.790564e+04   48977.379084
# min         0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%       148.000000  8.135750e+03  0.000000e+00  0.000000e+00       0.000000
# 50%      1235.000000  3.799650e+04  0.000000e+00  0.000000e+00       0.000000
# 75%      8160.000000  1.680360e+05  9.796750e+01  9.000000e+01      84.785000
# max    829111.000000  3.188720e+07  1.300000e+06  1.050000e+06  998426.000000
#
#           is_remote         views  is_sponsored     base_comp
# count  33246.000000  33246.000000  33246.000000  33246.000000
# mean       0.144438     45.424592      0.244150      0.401612
# std        0.351539    126.972720      0.429588      0.490232
# ...

# %%
df.shape
# Out:
# (33246, 24)

# %%
df['domain'].fillna(value='NaN', inplace=True)

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Co_Nm              0
# Co_Pg_Lstd         0
# Emp_Cnt            0
# Flw_Cnt            0
# Job_Ttl            0
# Job_Desc           0
# Is_Supvsr          0
# max_sal            0
# med_sal            0
# min_sal            0
# py_prd             0
# py_lstd            0
# wrk_typ            0
# loc                0
# st_code            0
# is_remote          0
# views              0
# app_typ            0
# app_is_off         0
# xp_lvl             0
# domain             0
# has_post_domain    0
# is_sponsored       0
# base_comp          0
# dtype: int64

# %%
df['max_sal'].describe()
# Out:
# count    3.324000e+04
# mean     3.185114e+04
# std      6.821805e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      9.787000e+01
# max      1.300000e+06
# Name: max_sal, dtype: float64

# %%
df['salary']=df['max_sal'].mean()+df['med_sal'].mean()+df['min_sal'].mean()

# %%
df=df.drop(['max_sal','med_sal','min_sal'],axis=1)

# %%
df.columns
# Out:
# Index(['Co_Nm', 'Co_Pg_Lstd', 'Emp_Cnt', 'Flw_Cnt', 'Job_Ttl', 'Job_Desc',
#        'Is_Supvsr', 'py_prd', 'py_lstd', 'wrk_typ', 'loc', 'st_code',
#        'is_remote', 'views', 'app_typ', 'app_is_off', 'xp_lvl', 'domain',
#        'has_post_domain', 'is_sponsored', 'base_comp', 'salary'],
#       dtype='object')

# %%
df['salary']
# Out:
# 0        82451.015634
# 1        82451.015634
# 2        82451.015634
# 3        82451.015634
# 4        82451.015634
#              ...
# 33241    82451.015634
# 33242    82451.015634
# 33243    82451.015634
# 33244    82451.015634
# 33245    82451.015634
# Name: salary, Length: 33240, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Co_Nm', 'Co_Pg_Lstd', 'Emp_Cnt', 'Flw_Cnt', 'Job_Ttl', 'Job_Desc',
#        'Is_Supvsr', 'py_prd', 'py_lstd', 'wrk_typ', 'loc', 'st_code',
#        'is_remote', 'views', 'app_typ', 'app_is_off', 'xp_lvl', 'domain',
#        'has_post_domain', 'is_sponsored', 'base_comp', 'salary'],
#       dtype='object')

# %%
plt.plot(df['Emp_Cnt'])

# %%
df1=df[['Emp_Cnt','Flw_Cnt','is_remote','views','is_sponsored','base_comp','salary']]

# %%
 sns.heatmap(df1.corr(),annot=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: >

# %%
plt.figure(figsize=(15,10))

plt.subplot(4,3,1)
sns.boxplot(df['Flw_Cnt'])

plt.subplot(4,3,2)
sns.boxplot(df['views'])

plt.subplot(4,3,3)
sns.boxplot(df['Emp_Cnt'])

plt.show()

# %%
plt.figure(figsize=(30,30))

sns.pairplot(df1, hue='Emp_Cnt', markers='*', dropna=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
